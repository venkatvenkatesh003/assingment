# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pds

# %%
url="https://www.flipkart.com/mobiles/~cs-81hziz7kkm/pr?sid=tyy%2C4io&collection-tab-name=iPhone+14+and+14+Plus&param=17326&ctx=...%3D%3D&fm=neo%2Fmerchandising&iid=M_76677016-c1b3-4ffb-826a-d0e9544c7639_4.RBK8YP30BKBH&ppt=None&ppn=None&ssid=n9n9pkj35s0000001680339652693&otracker=hp_omu_Top%2BOffers_1_4.dealCard.OMU_RBK8YP30BKBH_3&otracker1=hp_omu_PINNED_neo%2Fmerchandising_Top%2BOffers_NA_dealCard_cc_1_NA_view-all_3&cid=RBK8YP30BKBH"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
products=soup.select("._4rR01T")

# %%
products
# Out:
# [<div class="_4rR01T">APPLE iPhone 14 Plus (Midnight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Starlight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Starlight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Midnight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Purple, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 ((PRODUCT)RED, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Purple, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus ((PRODUCT)RED, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Purple, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Starlight, 256 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Midnight, 256 GB)</div>,
# ...

# %%
products_rating=soup.select("._3LWZlK")

# %%
products_rating
# Out:
# [<div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
# ...

# %%
products_price=soup.select("._1_WHN1")

# %%
products_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹79,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹71,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹79,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹71,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹79,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹71,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹70,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹79,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹79,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹71,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹89,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹89,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹81,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹89,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹89,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,09,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹81,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹81,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,09,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹81,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,09,999</div>,
# ...

# %%
product=pds.DataFrame['name']

# %%
product
# Out:
#                                            NAME
# 0       APPLE iPhone 14 Plus (Midnight, 128 GB)
# 1           APPLE iPhone 14 (Starlight, 128 GB)
# 2      APPLE iPhone 14 Plus (Starlight, 128 GB)
# 3            APPLE iPhone 14 (Midnight, 128 GB)
# 4           APPLE iPhone 14 Plus (Blue, 128 GB)
# 5              APPLE iPhone 14 (Purple, 128 GB)
# 6        APPLE iPhone 14 ((PRODUCT)RED, 128 GB)
# 7         APPLE iPhone 14 Plus (Purple, 128 GB)
# 8   APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)
# 9                APPLE iPhone 14 (Blue, 128 GB)
# 10  APPLE iPhone 14 Plus ((PRODUCT)RED, 256 GB)
# 11        APPLE iPhone 14 Plus (Purple, 256 GB)
# 12          APPLE iPhone 14 (Starlight, 256 GB)
# 13      APPLE iPhone 14 Plus (Midnight, 256 GB)
# 14     APPLE iPhone 14 Plus (Starlight, 256 GB)
# 15      APPLE iPhone 14 Plus (Midnight, 512 GB)
# 16       APPLE iPhone 14 ((PRODUCT)RED, 256 GB)
# 17           APPLE iPhone 14 (Midnight, 256 GB)
# 18          APPLE iPhone 14 Plus (Blue, 512 GB)
# ...

# %%
d=product.to_csv("C:/Users/Admin/Desktop/New folder.csv")

# %%
product
# Out:
#                                            NAME
# 0       APPLE iPhone 14 Plus (Midnight, 128 GB)
# 1           APPLE iPhone 14 (Starlight, 128 GB)
# 2      APPLE iPhone 14 Plus (Starlight, 128 GB)
# 3            APPLE iPhone 14 (Midnight, 128 GB)
# 4           APPLE iPhone 14 Plus (Blue, 128 GB)
# 5              APPLE iPhone 14 (Purple, 128 GB)
# 6        APPLE iPhone 14 ((PRODUCT)RED, 128 GB)
# 7         APPLE iPhone 14 Plus (Purple, 128 GB)
# 8   APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)
# 9                APPLE iPhone 14 (Blue, 128 GB)
# 10  APPLE iPhone 14 Plus ((PRODUCT)RED, 256 GB)
# 11        APPLE iPhone 14 Plus (Purple, 256 GB)
# 12          APPLE iPhone 14 (Starlight, 256 GB)
# 13      APPLE iPhone 14 Plus (Midnight, 256 GB)
# 14     APPLE iPhone 14 Plus (Starlight, 256 GB)
# 15      APPLE iPhone 14 Plus (Midnight, 512 GB)
# 16       APPLE iPhone 14 ((PRODUCT)RED, 256 GB)
# 17           APPLE iPhone 14 (Midnight, 256 GB)
# 18          APPLE iPhone 14 Plus (Blue, 512 GB)
# ...

# %%
file=pds.read_csv("C:/Users/Admin/Desktop/New folder.csv")

# %%
file
# Out:
#     Unnamed: 0                                         NAME
# 0            0      APPLE iPhone 14 Plus (Midnight, 128 GB)
# 1            1          APPLE iPhone 14 (Starlight, 128 GB)
# 2            2     APPLE iPhone 14 Plus (Starlight, 128 GB)
# 3            3           APPLE iPhone 14 (Midnight, 128 GB)
# 4            4          APPLE iPhone 14 Plus (Blue, 128 GB)
# 5            5             APPLE iPhone 14 (Purple, 128 GB)
# 6            6       APPLE iPhone 14 ((PRODUCT)RED, 128 GB)
# 7            7        APPLE iPhone 14 Plus (Purple, 128 GB)
# 8            8  APPLE iPhone 14 Plus ((PRODUCT)RED, 128 GB)
# 9            9               APPLE iPhone 14 (Blue, 128 GB)
# 10          10  APPLE iPhone 14 Plus ((PRODUCT)RED, 256 GB)
# 11          11        APPLE iPhone 14 Plus (Purple, 256 GB)
# 12          12          APPLE iPhone 14 (Starlight, 256 GB)
# 13          13      APPLE iPhone 14 Plus (Midnight, 256 GB)
# 14          14     APPLE iPhone 14 Plus (Starlight, 256 GB)
# ...

# %%
edit=file['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
edit
